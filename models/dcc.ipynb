# %%
import pandas as pd 
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import importlib                      
from pathlib import Path
from rpy2.robjects import numpy2ri, StrVector
import statsmodels.api as sm
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter


forecast = importr("forecast")
rugarch = importr("rugarch")
rmgarch = importr("rmgarch")
print("Loaded:", rmgarch.__rname__, rugarch.__rname__)
# Out:
# Loaded: rmgarch rugarch

# %%
data = pd.read_csv('../data/log_returns.csv', index_col=0, parse_dates=True)
data.columns
# Out:
# Index(['US_EQUITY', 'INTL_EQUITY', 'US_BONDS', 'INTL_BONDS', 'US_REIT',
#        'INTL_REIT', 'GOLD', 'BTC'],
#       dtype='object')

# %%
WINDOW = 120
N_AHEAD = 21
DCC_DIST = "mvt"  # multivariate t-distribution
